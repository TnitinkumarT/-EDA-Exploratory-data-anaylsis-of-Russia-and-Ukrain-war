# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ru = pd.read_csv(r'C:\Users\Gattu\Desktop\New folder (2)\russia_losses_equipment.csv')
ru
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0   2022-02-25    2        10           7    80   516               49    4
# 1   2022-02-26    3        27          26   146   706               49    4
# 2   2022-02-27    4        27          26   150   706               50    4
# 3   2022-02-28    5        29          29   150   816               74   21
# 4   2022-03-01    6        29          29   198   846               77   24
# 5   2022-03-02    7        30          31   211   862               85   40
# 6   2022-03-03    8        30          31   217   900               90   42
# 7   2022-03-04    9        33          37   251   939              105   50
# 8   2022-03-05   10        39          40   269   945              105   50
# 9   2022-03-06   11        44          48   285   985              109   50
# 10  2022-03-07   12        46          68   290   999              117   50
# ...

# %%
len(ru)
# Out:
# 45

# %%
'''
    EDA = EXPLORATORY DATA ANALYSIS
    
    WE CAN ANALYZE THE DATA IN 2 WAYS
    1)WE CAN ANALYZE DATA WITH THE HELP OF MATHS AND STATISTICS
     by using min,max,mean,median,mode and STANDARD DEVIATIONB AND FREQUENCY
    
    2)WE CAN ALSO ANALYZE THE DATA WITH YHE HELP OF PICTURES
     by using softwares like matplotlib and seaborn
    '''
# Out:
# '\n    EDA = EXPLORATORY DATA ANALYSIS\n    \n    WE CAN ANALYZE THE DATA IN 2 WAYS\n    1)WE CAN ANALYZE DATA WITH THE HELP OF MATHS AND STATISTICS\n     by using min,max,mean,median,mode and STANDARD DEVIATIONB AND FREQUENCY\n    \n    2)WE CAN ALSO ANALYZE THE DATA WITH YHE HELP OF PICTURES\n     by using softwares like matplotlib and seaborn\n    '

# %%
ru.describe()
# Out:
#              day    aircraft  helicopter        tank          APC  \
# count  45.000000   45.000000   45.000000   45.000000    45.000000
# mean   24.000000   89.866667   96.577778  450.133333  1385.222222
# std    13.133926   45.086583   40.575121  181.772785   396.810344
# min     2.000000   10.000000    7.000000   80.000000   516.000000
# 25%    13.000000   48.000000   80.000000  303.000000  1036.000000
# 50%    24.000000   95.000000  115.000000  466.000000  1470.000000
# 75%    35.000000  131.000000  131.000000  605.000000  1723.000000
# max    46.000000  152.000000  137.000000  722.000000  1911.000000
#
#        field artillery         MRL  military auto  fuel tank       drone  \
# count        45.000000   45.000000      45.000000  45.000000   45.000000
# mean        209.866667   71.333333     832.911111  66.355556   39.333333
# std         100.564678   29.733666     398.363517   7.317959   39.616342
# min          49.000000    4.000000     100.000000  60.000000    0.000000
# ...

# %%
ru.isnull().head(2)
# Out:
#     date    day  aircraft  helicopter   tank    APC  field artillery    MRL  \
# 0  False  False     False       False  False  False            False  False
# 1  False  False     False       False  False  False            False  False
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0          False      False  False       False                  False
# 1          False      False  False       False                  False
#
#    special equipment  mobile SRBM system
# 0               True                True
# 1               True                True

# %%
ru.isna().sum() # we can even us isna() it works for both NaN and none same like isnull()
# Out:
# date                     0
# day                      0
# aircraft                 0
# helicopter               0
# tank                     0
# APC                      0
# field artillery          0
# MRL                      0
# military auto            0
# fuel tank                0
# drone                    0
# naval ship               0
# anti-aircraft warfare    0
# special equipment        0
# mobile SRBM system       0
# dtype: int64

# %%
ru.fillna({'special equipment':0, 'mobile SRBM system':1},inplace=True)
ru.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
# 2  2022-02-27    4        27          26   150  706               50    4
# 3  2022-02-28    5        29          29   150  816               74   21
# 4  2022-03-01    6        29          29   198  846               77   24
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
# 2            130         60      2           2                      0
# 3            291         60      3           2                      5
# 4            305         60      3           2                      7
#
#    special equipment  mobile SRBM system
# 0                0.0                 1.0
# ...

# %%
x = [i for i in range(1,46)]
y = ru['helicopter']
y2 = ru['tank']

plt.plot(x,y,'o-r',label='helicopters')
plt.plot(x,y2,'*:b',label='tanks')
plt.legend()
plt.plot()
plt.show()
